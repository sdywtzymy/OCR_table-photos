# %%
import cv2
import pytesseract
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# /Users/mingyu/anaconda3/envs/opencv/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.7
#   return f(*args, **kwds)

# %%
sample_1_img = cv2.imread("sample_1.jpg")

# %%
sample_1_img.shape
# Out:
# (2339, 1654, 3)

# %%
plt.figure(figsize=(100,40))
plt.imshow(sample_1_img)
plt.show()

# %%
sample_1_content = pytesseract.image_to_string(sample_1_img, lang='chi_sim')

# %%
sample_1_gray = cv2.cvtColor(sample_1_img, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(100,40))
plt.imshow(sample_1_gray,cmap = "gray")
plt.show()

# %%
class tableDetect():
